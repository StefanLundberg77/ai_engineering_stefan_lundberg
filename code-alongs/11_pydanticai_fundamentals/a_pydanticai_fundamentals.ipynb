# %% [markdown]
# # PydanticAI fundamentals

# %%
from pydantic_ai import Agent
from dotenv import load_dotenv

load_dotenv()

# GOOGLE_API_KEY or GEMINI_API_KEY should be defined in .env
agent = Agent(model="google-gla:gemini-2.5-flash")

result = await agent.run("Give me a programming joke")

result
# Out:
# AgentRunResult(output='Here\'s a classic:\n\nA programmer\'s wife tells him, "Could you please go to the store and pick up a loaf of bread? And if they have eggs, get a dozen."\n\nThe programmer returns home with 12 loaves of bread.\n\nHis wife asks, "Why on earth did you buy 12 loaves of bread?!"\n\nHe replies, "They had eggs."')

# %%
print(result.output)
# Out:
# Here's a classic:
#
# A programmer's wife tells him, "Could you please go to the store and pick up a loaf of bread? And if they have eggs, get a dozen."
#
# The programmer returns home with 12 loaves of bread.
#
# His wife asks, "Why on earth did you buy 12 loaves of bread?!"
#
# He replies, "They had eggs."

# %%
result = await agent.run("Give me an IT employee working in Sweden, shortly")
result
# Out:
# AgentRunResult(output='**Elara Svensson**\n*   **Role:** DevOps Engineer\n*   **Location:** Stockholm, Sweden\n*   **Company:** Mid-sized SaaS tech firm\n\nElara, in her late 20s, designs and maintains the infrastructure for her company\'s cloud-based products. She\'s fluent in Python, adept with AWS, Kubernetes, and Terraform, and focuses on automation, scalability, and security. Elara values her work-life balance, enjoys her daily "fika" (coffee break) with colleagues, and often bikes to work, embracing Sweden\'s outdoor culture. She\'s known for her pragmatic problem-solving and collaborative spirit in her company\'s English-first tech environment.')

# %%
print(result.output)
# Out:
# **Elara Svensson**
# *   **Role:** DevOps Engineer
# *   **Location:** Stockholm, Sweden
# *   **Company:** Mid-sized SaaS tech firm
#
# Elara, in her late 20s, designs and maintains the infrastructure for her company's cloud-based products. She's fluent in Python, adept with AWS, Kubernetes, and Terraform, and focuses on automation, scalability, and security. Elara values her work-life balance, enjoys her daily "fika" (coffee break) with colleagues, and often bikes to work, embracing Sweden's outdoor culture. She's known for her pragmatic problem-solving and collaborative spirit in her company's English-first tech environment.

# %%
with open("employee.md", "w") as file:
    file.write(result.output)

# %% [markdown]
# ## pydantic to structure the output

# %%
from pydantic import BaseModel, Field

class EmployeeModel(BaseModel):
    name: str = Field(description="name of employee") 
    age: int = Field(description="age of employee", gt = 17, lt = 70)
    salary: int = Field(description="monthly salary of employee between 35000 and 70000", gt = 35000, lt=70000)
    role: str = Field(description="role of the employee, what he/she is working with")

result = await agent.run("Give me an IT employee working in Sweden", output_type=EmployeeModel)
result
# Out:
# AgentRunResult(output=EmployeeModel(name='John Doe', age=30, salary=50000, role='Software Engineer'))

# %%
employee = result.output
employee
# Out:
# EmployeeModel(name='John Doe', age=30, salary=50000, role='Software Engineer')

# %%
employee.name, employee.role
# Out:
# ('John Doe', 'Software Engineer')

# %%
isinstance(employee, EmployeeModel), isinstance(employee, BaseModel)
# Out:
# (True, True)

# %% [markdown]
# simulate more employees

# %%
result = await agent.run("""
                         Give me 10 employees in AI and data engineering field
                         Generate different roles, the more senior the role, the higher the salary
                         """,
                         output_type=list[EmployeeModel])

result
# Out:
# AgentRunResult(output=[EmployeeModel(name='Alice Smith', age=28, salary=40000, role='Junior Data Engineer'), EmployeeModel(name='Bob Johnson', age=32, salary=45000, role='Data Engineer'), EmployeeModel(name='Charlie Brown', age=38, salary=50000, role='Senior Data Engineer'), EmployeeModel(name='Diana Prince', age=45, salary=55000, role='Lead Data Engineer'), EmployeeModel(name='Eve Adams', age=29, salary=41000, role='Junior AI Engineer'), EmployeeModel(name='Frank White', age=34, salary=46000, role='AI Engineer'), EmployeeModel(name='Grace Lee', age=39, salary=51000, role='Senior AI Engineer'), EmployeeModel(name='Harry Kim', age=46, salary=56000, role='Lead AI Engineer'), EmployeeModel(name='Ivy Wang', age=42, salary=60000, role='AI Research Scientist'), EmployeeModel(name='Jack Chen', age=48, salary=68000, role='Machine Learning Architect')])

# %%
result.output[0].model_dump()
# Out:
# {'name': 'Alice Smith',
#  'age': 28,
#  'salary': 40000,
#  'role': 'Junior Data Engineer'}

# %%
employees = [employee.model_dump() for employee in result.output]
employees[:3]
# Out:
# [{'name': 'Alice Smith',
#   'age': 28,
#   'salary': 40000,
#   'role': 'Junior Data Engineer'},
#  {'name': 'Bob Johnson', 'age': 32, 'salary': 45000, 'role': 'Data Engineer'},
#  {'name': 'Charlie Brown',
#   'age': 38,
#   'salary': 50000,
#   'role': 'Senior Data Engineer'}]

# %%
import pandas as pd 

pd.DataFrame(employees)
# Out:
#             name  age  salary                        role
# 0    Alice Smith   28   40000        Junior Data Engineer
# 1    Bob Johnson   32   45000               Data Engineer
# 2  Charlie Brown   38   50000        Senior Data Engineer
# 3   Diana Prince   45   55000          Lead Data Engineer
# 4      Eve Adams   29   41000          Junior AI Engineer
# 5    Frank White   34   46000                 AI Engineer
# 6      Grace Lee   39   51000          Senior AI Engineer
# 7      Harry Kim   46   56000            Lead AI Engineer
# 8       Ivy Wang   42   60000       AI Research Scientist
# 9      Jack Chen   48   68000  Machine Learning Architect
